# %% [markdown]
# <img src="https://imgur.com/3U3hI1u.png" width="100%" />

# %% [markdown]
# #### Boas vindas a sua segunda e última tarefa de Aprendizado por Reforço!
#
# Neste exercício, você deverá implementar e comparar diferentes algoritmos de **Aprendizado por Reforço Profundo** utilizando a biblioteca _[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)_.
#
# A _Stable Baselines_ é uma biblioteca de Aprendizado por Reforço que implementa diversos algoritmos de agentes, além de várias funcionalidades úteis para seu treinamento. Suas implementações são bem simples e intuitivas, mas sem deixarem de ser otimizadas e poderosas, buscando facilitar o desenvolvimento de projetos de reforço de alta qualidade.
#
# Antes de começar a tarefa, é importante acessar e se familiarizar com o tutorial da biblioteca disponível neste repositório! Depois de rodar o guia, você já estará capaz de completar este trabalho.

# %% [markdown]
# ## Escolha do Ambiente
#
# Antes de analisar o possíveis algoritmos, o primeiro passo é escolher qual ambiente você quer resolver! Para esta tarefa, separamos quatro possíveis ambientes diferentes, em ordem de dificuldade, que você poderá escolher: **Pong**, **Lunar Lander** e **Lunar Lander Continuous**. Lembrando que, quanto mais difícil um ambiente, mais demorado será o treinamento.
#
# A seguir, estão as descrições de cada um deles:

# %% [markdown]
# <h2 align="center">Pong</h2>
# <img src="https://imgur.com/vdVCmvo.gif" width=50% />
#
# **Pong** é o ambiente de Aprendizado por Reforço criado pelo Turing que simula o jogo de *Pong*, no qual existem duas "raquetes" e uma bola, e o objetivo de cada uma das raquetes é não somente evitar que a bola passe por ela, como também fazer com que esta passe pela linha que a outra raquete protege.

# %% [markdown]
# ### Características do Ambiente
#
# O **Espaço de Observação** do ambiente é definido por 2 informações.
#
# | Estado    | Informação                            |
# | :-------- | :------------------------------------ |
# | 0         | Distância _x_ entre a bola e o agente |
# | 1         | Distância _y_ entre a bola e o agente |
#
# Já o **Espaço de Ação** é composto por três ações: mover o jogador para cima, baixo, ou deixá-lo parado.
#
# | Ação | Significado      |
# | :--- | :--------------- |
# | 0    | Ficar parado     |
# | 1    | Mover para baixo |
# | 2    | Mover para cima  |
#
# Por fim, cada vez que tomamos uma ação, recebemos do ambiente uma **recompensa**, conforme a tabela abaixo:
#
# | Ocorrência          | Recompensa |
# | :------------------ | ---------: |
# | Ponto do Agente     | $+500$     |
# | Ponto do Oponente   | $-500$     |
# | Vitória do Agente   | $+2000$    |
# | Vitória do Oponente | $-2000$    |
#
# O primeiro jogador a fazer quatro pontos ganha o jogo. Além disso, as recompensas são cumulativas. Isso significa que se o oponente fizer um ponto _e_ ganhar o jogo, a recompensa é de $-2500$.

# %% [markdown]
# ### Instalação
#
# Para instalar os ambientes criados pelo Turing, basta rodar o seguinte comando no notebook (se preferir, também pode rodar no terminal; é só tirar o ponto de exclamação do começo da linha):

# %%
# !pip install -U turing-envs
# Out:
# Requirement already satisfied: turing-envs in c:\users\maria\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: gym in c:\users\maria\anaconda3\lib\site-packages (from turing-envs) (0.19.0)
# Requirement already satisfied: pygame in c:\users\maria\anaconda3\lib\site-packages (from turing-envs) (2.1.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\maria\anaconda3\lib\site-packages (from gym->turing-envs) (1.20.3)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\maria\anaconda3\lib\site-packages (from gym->turing-envs) (1.6.0)

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\maria\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\maria\anaconda3\lib\site-packages (from gym) (1.6.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\maria\anaconda3\lib\site-packages (from gym) (1.20.3)

# %%
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in c:\users\maria\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: pandas in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (1.3.4)
# Requirement already satisfied: numpy in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (3.4.3)
# Requirement already satisfied: cloudpickle in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (1.6.0)
# Requirement already satisfied: gym<0.20,>=0.17 in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (0.19.0)
# Requirement already satisfied: torch>=1.8.1 in c:\users\maria\anaconda3\lib\site-packages (from stable_baselines3) (1.10.2)
# Requirement already satisfied: typing-extensions in c:\users\maria\anaconda3\lib\site-packages (from torch>=1.8.1->stable_baselines3) (3.10.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\maria\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\maria\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\maria\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\maria\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maria\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: six in c:\users\maria\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\maria\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2021.3)

# %% [markdown]
# Com o ambiente do Turing instalado, podemos testar um modelo! Para isso, vamos precisar de 2 bibliotecas: **gym** (para inicialização dos ambientes) e **stable_baselines3** (para inicialização e avaliação dos modelos):

# %%
import gym 
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO

# Definindo ambiente
env = gym.make("turing_envs:pong-normal-v0")

# Definindo modelo
model = PPO("MlpPolicy", env, seed=1, verbose=1)

# Avaliando o agente
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, deterministic=True)

print(f"Recompensa Média: {mean_reward:.2f} +/- {std_reward}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Recompensa Média: -3750.00 +/- 335.4101966249685

# %% [markdown]
# <h2 align="center">Lunar Lander</h2>
#
# <img src="https://raw.githubusercontent.com/fakemonk1/Reinforcement-Learning-Lunar_Lander/master/images/3.gif" width=50% />
#
# **Lunar Lander** é um ambiente do Gym que simula o pouso de um módulo lunar na Lua. O agente deve controlar os três motores do módulo para guiá-lo até a pista de pouso, sem gastar muita energia.

# %% [markdown]
# ### Características do Ambiente
#
# O **Espaço de Observação** do ambiente é definido por 8 informações.
#
# | Estado    | Informação                                     |
# | :-------- | :--------------------------------------------- |
# | 0         | Posição no eixo _x_ do módulo                  |
# | 1         | Posição no eixo _y_ do módulo                  |
# | 2         | Velocidade no eixo _x_ do módulo               |
# | 3         | Velocidade no eixo _y_ do módulo               |
# | 4         | Ângulo do módulo                               |
# | 5         | Velocidade angular do módulo                   |
# | 6         | Se a perna esquerda está em contato com o chão |
# | 7         | Se a perna direita está em contato com o chão  |
#
# Já o **Espaço de Ação** é composto por quatro ações: não fazer nada, acionar o motor esquerdo, acionar o motor principal ou acionar o motor direito.
#
# | Ação | Significado             |
# | :--- | :---------------------- |
# | 0    | Não fazer nada          |
# | 1    | Acionar motor esquerdo  |
# | 2    | Acionar motor principal |
# | 3    | Acionar motor direito   |
#
# Por fim, cada vez que tomamos uma ação, recebemos do ambiente uma **recompensa**, conforme a tabela abaixo:
#
# | Ocorrência              | Recompensa       |
# | :---------------------- | ---------------: |
# | Se aproximar da pista   | Até $+140$       |
# | Pousar                  | $+100$           |
# | Colidir                 | $-100$           |
# | Tocar uma perna no chão | $+10$            |
# | Acionar motor principal | $-0.3$ por frame |
#
# #### Lunar Lander Continuous
#
# Também existe uma versão contínua do ambiente do Lunar Lander, no qual podemos controlar a força que cada um dos motores do módulo exercerá. Nesse caso, teremos duas ações:
#
# | Ação | Intervalo  | Significado                          |
# | :--- | :--------: | :----------------------------------- |
# | 0    | $-1$ a $+1$ | Força do motor principal             |
# | 1    | $-1$ a $+1$ | Força dos motores esquerdo e direito |
#
# Na versão contínua, os algoritmos que poderemos usar serão diferentes, e o treinamento provavelmente será mais difícil.

# %% [markdown]
# ### Instalação
#
# Para instalar os ambientes do Gym que usam a engine Box2D, é necessário rodar os seguintes comandos numa célula do notebook (se preferir, também pode rodar no terminal; é só tirar o ponto de exclamação do começo da linha):
#
#
# **Windows**

# %%
# !conda install swig
# !pip install box2d box2d-kengz
# Out:
# Requirement already satisfied: box2d in c:\users\maria\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: box2d-kengz in c:\users\maria\anaconda3\lib\site-packages (2.3.3)

# %% [markdown]
# **Linux**

# %%
# !apt install swig
# !pip install -u 'gym[box2d]'

# %% [markdown]
# Em seguida, para criar o ambiente, roda-se a linha de código a seguir:

# %%
env = gym.make("LunarLander-v2")

# %% [markdown]
# ou

# %%
env = gym.make("LunarLanderContinuous-v2")

# %% [markdown]
# ### Exercício 1 - Testando Modelos
#
# Caro piloto, agora que você conhece esses dois ambientes, é hora de brincar com eles. Você deverá testar diferentes algoritmos (a seu critério), e ver sua recompensa média. Para ver quais as limitações dos modelos, veja esse [link](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html). Abaixo, criamos uma função que será útil para comparar os modelos posteriormente.

# %%
def getValues(model, env, n_episodes, info_dict):
    model_name = str(model.__class__).split(".")[-1][:-2]

    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_episodes, deterministic=True)
    
    info_dict[model_name] = {}
    info_dict[model_name]["mean_reward"] = mean_reward
    info_dict[model_name]["std_reward"] = std_reward
    
    return info_dict

algorithms_dict = {}

# %% [markdown]
# #### Treinando e Avaliando seu próprio modelo
#
# Primeiramente, agora você deve decidir em qual ambiente você deseja treinar seu agente. Para isto, basta tirar o comentário da linha referente ao ambiente escolhido:

# %%
env_name = "turing_envs:pong-normal-v0"
# env_name = "LunarLander-v2"
# env_name = "LunarLanderContinuous-v2"

# %% [markdown]
# Em seguida, você está livre para testar diferentes algoritmos para seu ambiente!

# %%
import os
# cria pasta de logs para todos os algoritmos
log_dir_pong = "./logs-pong/"
os.makedirs(log_dir_pong, exist_ok=True)

# %%
from stable_baselines3 import A2C # Importe o modelo do stable_baselines3
from stable_baselines3.common.monitor import Monitor

# Cria pasta de logs
log_dir_a2c = ".logs-pong/logs-a2c/"
os.makedirs(log_dir_a2c, exist_ok=True)

# Definindo o ambiente
env = gym.make(env_name)
env = Monitor(env, log_dir_a2c)

model = A2C("MlpPolicy", env, seed = 3, verbose = 1) # Defina o modelo
model.learn(total_timesteps = 400000) # Treine o modelo
n_episodes = 50 # Defina o número de episódios

# Avaliando o agente e guardando o desempenho no dicionário
algorithms_dict = getValues(model, env, n_episodes, algorithms_dict)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | time/                 |          |
# |    fps                | 975      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -18.5    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0987   |
# |    value_loss         | 0.00768  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 799      |
# |    ep_rew_mean        | -3.5e+03 |
# | time/                 |          |
# |    fps                | 1037     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -33.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.138   |
# |    value_loss         | 0.0171   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 635       |
# |    ep_rew_mean        | -3.5e+03  |
# | time/                 |           |
# |    fps                | 959       |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | -0.000861 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -0.00455  |
# |    value_loss         | 2.31e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 618      |
# |    ep_rew_mean        | -3.5e+03 |
# | time/                 |          |
# |    fps                | 994      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | -26.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0348   |
# |    value_loss         | 0.00206  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 618       |
# |    ep_rew_mean        | -3.5e+03  |
# | time/                 |           |
# |    fps                | 990       |
# |    iterations         | 500       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.513    |
# |    explained_variance | -3.14e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 0.0313    |
# |    value_loss         | 0.0504    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 580      |
# |    ep_rew_mean        | -3.7e+03 |
# | time/                 |          |
# |    fps                | 988      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.697   |
# |    explained_variance | 0.682    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.000508 |
# |    value_loss         | 0.000109 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 557       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 992       |
# |    iterations         | 700       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.907    |
# |    explained_variance | -60.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -0.136    |
# |    value_loss         | 0.0388    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 527       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 995       |
# |    iterations         | 800       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.816    |
# |    explained_variance | -1.01     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.0625   |
# |    value_loss         | 0.00781   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 506       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 995       |
# |    iterations         | 900       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -0.0197   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 0.00348   |
# |    value_loss         | 1.36e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 506       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 1000      |
# |    iterations         | 1000      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.626    |
# |    explained_variance | -20.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.0445   |
# |    value_loss         | 0.0471    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 587       |
# |    ep_rew_mean        | -3.72e+03 |
# | time/                 |           |
# |    fps                | 992       |
# |    iterations         | 1100      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -0.565    |
# |    explained_variance | 0.813     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -0.0189   |
# |    value_loss         | 0.000523  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 587       |
# |    ep_rew_mean        | -3.72e+03 |
# | time/                 |           |
# |    fps                | 995       |
# |    iterations         | 1200      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.93     |
# |    explained_variance | -0.103    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.00789   |
# |    value_loss         | 0.000162  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 626      |
# |    ep_rew_mean        | -3.7e+03 |
# | time/                 |          |
# |    fps                | 995      |
# |    iterations         | 1300     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.572   |
# |    explained_variance | -9.98    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0247  |
# |    value_loss         | 0.035    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 605       |
# |    ep_rew_mean        | -3.73e+03 |
# | time/                 |           |
# |    fps                | 1006      |
# |    iterations         | 1400      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.927    |
# |    explained_variance | -2.36e+05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 1.27      |
# |    value_loss         | 1.99      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 606       |
# |    ep_rew_mean        | -3.67e+03 |
# | time/                 |           |
# |    fps                | 1014      |
# |    iterations         | 1500      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -6.9      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.0262   |
# |    value_loss         | 0.0013    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 598       |
# |    ep_rew_mean        | -3.69e+03 |
# | time/                 |           |
# |    fps                | 1019      |
# |    iterations         | 1600      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -136      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.0231    |
# |    value_loss         | 0.00133   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 594       |
# |    ep_rew_mean        | -3.68e+03 |
# | time/                 |           |
# |    fps                | 1020      |
# |    iterations         | 1700      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.913    |
# |    explained_variance | -18.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.0135    |
# |    value_loss         | 0.000761  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 575      |
# |    ep_rew_mean        | -3.7e+03 |
# | time/                 |          |
# |    fps                | 1027     |
# |    iterations         | 1800     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.481   |
# |    explained_variance | 0.5      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0127  |
# |    value_loss         | 0.00615  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 574       |
# |    ep_rew_mean        | -3.72e+03 |
# | time/                 |           |
# |    fps                | 1034      |
# |    iterations         | 1900      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -1        |
# |    explained_variance | -276      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.115     |
# |    value_loss         | 0.0111    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 526       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1033      |
# |    iterations         | 2000      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.533    |
# |    explained_variance | 0.118     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.0156    |
# |    value_loss         | 0.00653   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 526       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1033      |
# |    iterations         | 2100      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.161    |
# |    explained_variance | 0.00521   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -14.2     |
# |    value_loss         | 1.46e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 526       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1029      |
# |    iterations         | 2200      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -0.479    |
# |    explained_variance | -15.9     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -0.00606  |
# |    value_loss         | 0.00492   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 544       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1031      |
# |    iterations         | 2300      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -0.234    |
# |    explained_variance | 0.595     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | 0.000676  |
# |    value_loss         | 0.00019   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 544       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1036      |
# |    iterations         | 2400      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.133    |
# |    explained_variance | -187      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 0.00659   |
# |    value_loss         | 0.0934    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 543       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1041      |
# |    iterations         | 2500      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -0.684    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.0277    |
# |    value_loss         | 0.00438   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 538       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1045      |
# |    iterations         | 2600      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -0.238    |
# |    explained_variance | -8.87     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -0.000672 |
# |    value_loss         | 0.000213  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 533      |
# |    ep_rew_mean        | -3.8e+03 |
# | time/                 |          |
# |    fps                | 1040     |
# |    iterations         | 2700     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | -0.0235  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.00218  |
# |    value_loss         | 0.000137 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 527       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 1043      |
# |    iterations         | 2800      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -0.657    |
# |    explained_variance | -40.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.101     |
# |    value_loss         | 0.0199    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 530       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 1040      |
# |    iterations         | 2900      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -0.419    |
# |    explained_variance | -7.66     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 0.000609  |
# |    value_loss         | 0.000433  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 532       |
# |    ep_rew_mean        | -3.82e+03 |
# | time/                 |           |
# |    fps                | 1045      |
# |    iterations         | 3000      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.909    |
# |    explained_variance | 0.158     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 0.00331   |
# |    value_loss         | 0.000202  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 522       |
# |    ep_rew_mean        | -3.83e+03 |
# | time/                 |           |
# |    fps                | 1048      |
# |    iterations         | 3100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.993    |
# |    explained_variance | -0.202    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.00968   |
# |    value_loss         | 0.000156  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 522       |
# |    ep_rew_mean        | -3.83e+03 |
# | time/                 |           |
# |    fps                | 1047      |
# |    iterations         | 3200      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.359    |
# |    explained_variance | -383      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.00964   |
# |    value_loss         | 0.0132    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 535       |
# |    ep_rew_mean        | -3.82e+03 |
# | time/                 |           |
# |    fps                | 1050      |
# |    iterations         | 3300      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.249    |
# |    explained_variance | -11.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -0.00953  |
# |    value_loss         | 0.0238    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 543       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 1054      |
# |    iterations         | 3400      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.79     |
# |    explained_variance | -6.85     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 0.0016    |
# |    value_loss         | 7.8e-05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 543       |
# |    ep_rew_mean        | -3.81e+03 |
# | time/                 |           |
# |    fps                | 1057      |
# |    iterations         | 3500      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.3      |
# |    explained_variance | -0.00237  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.00233  |
# |    value_loss         | 0.000996  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 548       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1060      |
# |    iterations         | 3600      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -0.644    |
# |    explained_variance | -1.92     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.0095    |
# |    value_loss         | 0.00037   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 554       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1063      |
# |    iterations         | 3700      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.778    |
# |    explained_variance | -153      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.0243   |
# |    value_loss         | 0.000434  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 554       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1066      |
# |    iterations         | 3800      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.689    |
# |    explained_variance | -80.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 0.0153    |
# |    value_loss         | 0.000544  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 554       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1069      |
# |    iterations         | 3900      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.438    |
# |    explained_variance | 0.569     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | 0.000423  |
# |    value_loss         | 7.14e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 574       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1069      |
# |    iterations         | 4000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.214    |
# |    explained_variance | -1.93     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 0.00577   |
# |    value_loss         | 0.0015    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 576       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1065      |
# |    iterations         | 4100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.709    |
# |    explained_variance | -10.8     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | 0.0728    |
# |    value_loss         | 0.0111    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 576       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1063      |
# |    iterations         | 4200      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.805    |
# |    explained_variance | -3.75     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 0.00124   |
# |    value_loss         | 6.15e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 576       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1064      |
# |    iterations         | 4300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.809    |
# |    explained_variance | -136      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -0.0732   |
# |    value_loss         | 0.0107    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 599       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1065      |
# |    iterations         | 4400      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.817    |
# |    explained_variance | 0.021     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 0.0128    |
# |    value_loss         | 0.00045   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 601       |
# |    ep_rew_mean        | -3.73e+03 |
# | time/                 |           |
# |    fps                | 1067      |
# |    iterations         | 4500      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.558    |
# |    explained_variance | -3.18     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 0.00375   |
# |    value_loss         | 0.000593  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 596       |
# |    ep_rew_mean        | -3.74e+03 |
# | time/                 |           |
# |    fps                | 1069      |
# |    iterations         | 4600      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.153    |
# |    explained_variance | -58.5     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 0.000525  |
# |    value_loss         | 0.00128   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 592       |
# |    ep_rew_mean        | -3.74e+03 |
# | time/                 |           |
# |    fps                | 1071      |
# |    iterations         | 4700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.798    |
# |    explained_variance | -2.12     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -0.0124   |
# |    value_loss         | 0.00103   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 591       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1073      |
# |    iterations         | 4800      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.486    |
# |    explained_variance | -96.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.0324   |
# |    value_loss         | 0.00173   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 587       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1075      |
# |    iterations         | 4900      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.386    |
# |    explained_variance | -44.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 0.0121    |
# |    value_loss         | 0.000153  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 585       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1077      |
# |    iterations         | 5000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.395    |
# |    explained_variance | -0.00173  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 0.00317   |
# |    value_loss         | 1.43e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 590       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1078      |
# |    iterations         | 5100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -0.264    |
# |    explained_variance | 0.827     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 0.000141  |
# |    value_loss         | 5.09e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 586       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1080      |
# |    iterations         | 5200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.41     |
# |    explained_variance | 0.000127  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 0.00168   |
# |    value_loss         | 0.000273  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 583       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1081      |
# |    iterations         | 5300      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.125    |
# |    explained_variance | 0.214     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 0.000237  |
# |    value_loss         | 0.000127  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 580       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1083      |
# |    iterations         | 5400      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.0862   |
# |    explained_variance | 0.091     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | 0.00025   |
# |    value_loss         | 0.000305  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 579       |
# |    ep_rew_mean        | -3.74e+03 |
# | time/                 |           |
# |    fps                | 1083      |
# |    iterations         | 5500      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -0.147    |
# |    explained_variance | 0.00747   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 0.000377  |
# |    value_loss         | 0.000188  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 580       |
# |    ep_rew_mean        | -3.75e+03 |
# | time/                 |           |
# |    fps                | 1084      |
# |    iterations         | 5600      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.706    |
# |    explained_variance | -7.04     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 0.000556  |
# |    value_loss         | 2.42e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 569       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1085      |
# |    iterations         | 5700      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -0.0754   |
# |    explained_variance | -3.48     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000194 |
# |    value_loss         | 0.00073   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 569       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1086      |
# |    iterations         | 5800      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.181    |
# |    explained_variance | 0.863     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -1.53e-05 |
# |    value_loss         | 2.2e-07   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 565       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1088      |
# |    iterations         | 5900      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -0.327    |
# |    explained_variance | -1.68     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | 0.00107   |
# |    value_loss         | 0.000189  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 565       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1089      |
# |    iterations         | 6000      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.473    |
# |    explained_variance | -4.07     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -0.00422  |
# |    value_loss         | 0.001     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 561       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1090      |
# |    iterations         | 6100      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.618    |
# |    explained_variance | -26.3     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | 0.0495    |
# |    value_loss         | 0.00338   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 560       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1090      |
# |    iterations         | 6200      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.233    |
# |    explained_variance | -0.492    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | 1.62e-05  |
# |    value_loss         | 5.32e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 559       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1091      |
# |    iterations         | 6300      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.69     |
# |    explained_variance | -1.19e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0.0063   |
# |    value_loss         | 0.000221  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 559       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1093      |
# |    iterations         | 6400      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.934    |
# |    explained_variance | -15.2     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -0.00124  |
# |    value_loss         | 4.74e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 559       |
# |    ep_rew_mean        | -3.79e+03 |
# | time/                 |           |
# |    fps                | 1094      |
# |    iterations         | 6500      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.377    |
# |    explained_variance | -219      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | 0.00402   |
# |    value_loss         | 0.00209   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 571       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1095      |
# |    iterations         | 6600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.455    |
# |    explained_variance | -0.674    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.000124 |
# |    value_loss         | 1.74e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 569       |
# |    ep_rew_mean        | -3.78e+03 |
# | time/                 |           |
# |    fps                | 1095      |
# |    iterations         | 6700      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.234    |
# |    explained_variance | -0.992    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.000106 |
# |    value_loss         | 4.72e-06  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 574       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1096      |
# |    iterations         | 6800      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.944    |
# |    explained_variance | -1.78e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | 0.00534   |
# |    value_loss         | 6.12e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 574       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1097      |
# |    iterations         | 6900      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -0.266    |
# |    explained_variance | -2.77     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 1.27e-05  |
# |    value_loss         | 5.63e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1098      |
# |    iterations         | 7000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -0.234    |
# |    explained_variance | 0.707     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000212 |
# |    value_loss         | 1.53e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 7100      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.119    |
# |    explained_variance | 0.903     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 2.09e-05  |
# |    value_loss         | 9e-07     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1099      |
# |    iterations         | 7200      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.0739   |
# |    explained_variance | -65.1     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -4.94e-06 |
# |    value_loss         | 2.69e-07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 582       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1100      |
# |    iterations         | 7300      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -0.193    |
# |    explained_variance | 0.00865   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 0.00542   |
# |    value_loss         | 4.44e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 599       |
# |    ep_rew_mean        | -3.76e+03 |
# | time/                 |           |
# |    fps                | 1101      |
# |    iterations         | 7400      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -0.0825   |
# |    explained_variance | -0.00926  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | 0.000131  |
# |    value_loss         | 9.24e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 600       |
# |    ep_rew_mean        | -3.77e+03 |
# | time/                 |           |
# |    fps                | 1102      |
# |    iterations         | 7500      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 37500     |
# ...
# |    policy_loss        | 0.000779 |
# |    value_loss         | 1.17e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.61e+03 |
# |    ep_rew_mean        | -860     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 77600    |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.211   |
# |    explained_variance | -0.395   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 77599    |
# |    policy_loss        | 5.88e-05 |
# |    value_loss         | 3.76e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.6e+03  |
# |    ep_rew_mean        | -870     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 77700    |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 388500   |
# | train/                |          |
# |    entropy_loss       | -0.0639  |
# |    explained_variance | -282     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 77699    |
# |    policy_loss        | 1.03e-05 |
# |    value_loss         | 1.81e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.6e+03  |
# |    ep_rew_mean        | -870     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 77800    |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 389000   |
# | train/                |          |
# |    entropy_loss       | -0.172   |
# |    explained_variance | -6.45    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 77799    |
# |    policy_loss        | 0.00666  |
# |    value_loss         | 0.000866 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.6e+03   |
# |    ep_rew_mean        | -870      |
# | time/                 |           |
# |    fps                | 1121      |
# |    iterations         | 77900     |
# |    time_elapsed       | 347       |
# |    total_timesteps    | 389500    |
# | train/                |           |
# |    entropy_loss       | -0.000787 |
# |    explained_variance | -0.345    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 77899     |
# |    policy_loss        | 4.07e-07  |
# |    value_loss         | 4.28e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78000    |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 390000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | -67.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 77999    |
# |    policy_loss        | -0.00037 |
# |    value_loss         | 4.37e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78100    |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 390500   |
# | train/                |          |
# |    entropy_loss       | -0.508   |
# |    explained_variance | -382     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78099    |
# |    policy_loss        | 0.00407  |
# |    value_loss         | 5.92e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78200    |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 391000   |
# | train/                |          |
# |    entropy_loss       | -0.513   |
# |    explained_variance | -24      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78199    |
# |    policy_loss        | 0.00082  |
# |    value_loss         | 3.11e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -885      |
# | time/                 |           |
# |    fps                | 1121      |
# |    iterations         | 78300     |
# |    time_elapsed       | 349       |
# |    total_timesteps    | 391500    |
# | train/                |           |
# |    entropy_loss       | -0.463    |
# |    explained_variance | -2.99e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 78299     |
# |    policy_loss        | 0.000263  |
# |    value_loss         | 4.94e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78400    |
# |    time_elapsed       | 349      |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.209   |
# |    explained_variance | -325     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78399    |
# |    policy_loss        | 0.000161 |
# |    value_loss         | 1.04e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78500    |
# |    time_elapsed       | 349      |
# |    total_timesteps    | 392500   |
# | train/                |          |
# |    entropy_loss       | -0.202   |
# |    explained_variance | -10.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78499    |
# |    policy_loss        | 1.87e-06 |
# |    value_loss         | 7.27e-09 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -885     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78600    |
# |    time_elapsed       | 350      |
# |    total_timesteps    | 393000   |
# | train/                |          |
# |    entropy_loss       | -0.272   |
# |    explained_variance | -358     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78599    |
# |    policy_loss        | 3.21e-07 |
# |    value_loss         | 3.28e-10 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -885      |
# | time/                 |           |
# |    fps                | 1121      |
# |    iterations         | 78700     |
# |    time_elapsed       | 350       |
# |    total_timesteps    | 393500    |
# | train/                |           |
# |    entropy_loss       | -0.674    |
# |    explained_variance | -143      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 78699     |
# |    policy_loss        | -0.000288 |
# |    value_loss         | 6.12e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1121     |
# |    iterations         | 78800    |
# |    time_elapsed       | 351      |
# |    total_timesteps    | 394000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.00856  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 78799    |
# |    policy_loss        | -1.7e-05 |
# |    value_loss         | 4.61e-09 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -895      |
# | time/                 |           |
# |    fps                | 1121      |
# |    iterations         | 78900     |
# |    time_elapsed       | 351       |
# |    total_timesteps    | 394500    |
# | train/                |           |
# |    entropy_loss       | -0.655    |
# |    explained_variance | -0.148    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 78899     |
# |    policy_loss        | -9.37e-05 |
# |    value_loss         | 4.77e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -895      |
# | time/                 |           |
# |    fps                | 1122      |
# |    iterations         | 79000     |
# |    time_elapsed       | 352       |
# |    total_timesteps    | 395000    |
# | train/                |           |
# |    entropy_loss       | -0.313    |
# |    explained_variance | -0.551    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 78999     |
# |    policy_loss        | -8.94e-05 |
# |    value_loss         | 6.21e-08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -895      |
# | time/                 |           |
# |    fps                | 1122      |
# |    iterations         | 79100     |
# |    time_elapsed       | 352       |
# |    total_timesteps    | 395500    |
# | train/                |           |
# |    entropy_loss       | -0.53     |
# |    explained_variance | -0.00209  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 79099     |
# |    policy_loss        | -2.23e-05 |
# |    value_loss         | 2.67e-09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -895      |
# | time/                 |           |
# |    fps                | 1122      |
# |    iterations         | 79200     |
# |    time_elapsed       | 352       |
# |    total_timesteps    | 396000    |
# | train/                |           |
# |    entropy_loss       | -0.255    |
# |    explained_variance | -44.7     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 79199     |
# |    policy_loss        | -7.16e-05 |
# |    value_loss         | 6.51e-07  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79300    |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 396500   |
# | train/                |          |
# |    entropy_loss       | -0.35    |
# |    explained_variance | 0.191    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79299    |
# |    policy_loss        | 9.68e-05 |
# |    value_loss         | 3.94e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79400    |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 397000   |
# | train/                |          |
# |    entropy_loss       | -0.19    |
# |    explained_variance | 0.000182 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79399    |
# |    policy_loss        | 1.25e-05 |
# |    value_loss         | 6.09e-08 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79500    |
# |    time_elapsed       | 354      |
# |    total_timesteps    | 397500   |
# | train/                |          |
# |    entropy_loss       | -0.218   |
# |    explained_variance | -265     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79499    |
# |    policy_loss        | 3.02e-05 |
# |    value_loss         | 2.32e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79600    |
# |    time_elapsed       | 354      |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.406   |
# |    explained_variance | 0.443    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79599    |
# |    policy_loss        | 6.55e-05 |
# |    value_loss         | 2.08e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79700    |
# |    time_elapsed       | 354      |
# |    total_timesteps    | 398500   |
# | train/                |          |
# |    entropy_loss       | -0.218   |
# |    explained_variance | 0.612    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79699    |
# |    policy_loss        | 3.96e-05 |
# |    value_loss         | 7.27e-07 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79800    |
# |    time_elapsed       | 355      |
# |    total_timesteps    | 399000   |
# | train/                |          |
# |    entropy_loss       | -0.447   |
# |    explained_variance | -0.00371 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79799    |
# |    policy_loss        | 0.000243 |
# |    value_loss         | 1.76e-06 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.58e+03 |
# |    ep_rew_mean        | -895     |
# | time/                 |          |
# |    fps                | 1122     |
# |    iterations         | 79900    |
# |    time_elapsed       | 355      |
# |    total_timesteps    | 399500   |
# | train/                |          |
# |    entropy_loss       | -0.224   |
# |    explained_variance | -2.54    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 79899    |
# |    policy_loss        | 3.41e-05 |
# |    value_loss         | 8.9e-07  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.58e+03  |
# |    ep_rew_mean        | -895      |
# | time/                 |           |
# |    fps                | 1122      |
# |    iterations         | 80000     |
# |    time_elapsed       | 356       |
# |    total_timesteps    | 400000    |
# | train/                |           |
# |    entropy_loss       | -0.28     |
# |    explained_variance | -2.83     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 79999     |
# |    policy_loss        | -9.49e-06 |
# |    value_loss         | 4.64e-10  |
# -------------------------------------

# %%
from stable_baselines3 import DQN # Importe o modelo do stable_baselines3

# Cria pasta de logs
log_dir_dqn = ".logs-pong/logs-dqn/"
os.makedirs(log_dir_dqn, exist_ok=True)

# Definindo o ambiente
env = gym.make(env_name)
env = Monitor(env, log_dir_dqn)

model = DQN("MlpPolicy", env, seed = 3, verbose = 1) # Defina o modelo
model.learn(total_timesteps = 400000) # Treine o modelo
n_episodes = 50 # Defina o número de episódios

# Avaliando o agente e guardando o desempenho no dicionário
algorithms_dict = getValues(model, env, n_episodes, algorithms_dict)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | -3.5e+03 |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6309     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2927     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 624       |
# |    ep_rew_mean      | -3.69e+03 |
# |    exploration_rate | 0.881     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 6192      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 4992      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 635       |
# |    ep_rew_mean      | -3.71e+03 |
# |    exploration_rate | 0.819     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 6024      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 7620      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 637       |
# |    ep_rew_mean      | -3.62e+03 |
# |    exploration_rate | 0.758     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 5859      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 10194     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 659      |
# |    ep_rew_mean      | -3.6e+03 |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5993     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13184    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 650       |
# |    ep_rew_mean      | -3.67e+03 |
# |    exploration_rate | 0.629     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 6065      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 15605     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 699       |
# |    ep_rew_mean      | -3.61e+03 |
# |    exploration_rate | 0.535     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 6166      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 19583     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 693       |
# |    ep_rew_mean      | -3.59e+03 |
# |    exploration_rate | 0.474     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 6205      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 22168     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 696      |
# |    ep_rew_mean      | -3.6e+03 |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 6243     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 25054    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 691       |
# |    ep_rew_mean      | -3.59e+03 |
# |    exploration_rate | 0.343     |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 6267      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 27658     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 677       |
# |    ep_rew_mean      | -3.62e+03 |
# |    exploration_rate | 0.293     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 6285      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 29772     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 663       |
# |    ep_rew_mean      | -3.65e+03 |
# |    exploration_rate | 0.245     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 6295      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 31807     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 647       |
# |    ep_rew_mean      | -3.65e+03 |
# |    exploration_rate | 0.2       |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 6302      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 33668     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 639       |
# |    ep_rew_mean      | -3.67e+03 |
# |    exploration_rate | 0.15      |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 6314      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 35776     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 629       |
# |    ep_rew_mean      | -3.68e+03 |
# |    exploration_rate | 0.103     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 6321      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 37749     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 618      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.0611   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 6329     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 39531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 622      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 6341     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 42292    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 627       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 6351      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 45137     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 641       |
# |    ep_rew_mean      | -3.71e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 6367      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 48751     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 659       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 5356      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 52748     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.105     |
# |    n_updates        | 686       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 658       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 4670      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 55300     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.5      |
# |    n_updates        | 1324      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 657       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 4215      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 57844     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0437    |
# |    n_updates        | 1960      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 651       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 3907      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 59913     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 78.3      |
# |    n_updates        | 2478      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 651      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3626     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 62482    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 3120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 660      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3331     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 65971    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 3992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 659      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3134     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 68844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.7     |
# |    n_updates        | 4710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 653      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3046     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 70339    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 5084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 650      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2930     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 72588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 5646     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 642       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 2808      |
# |    time_elapsed     | 26        |
# |    total_timesteps  | 74425     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0501    |
# |    n_updates        | 6106      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 638       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 2649      |
# |    time_elapsed     | 29        |
# |    total_timesteps  | 76969     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.7      |
# |    n_updates        | 6742      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 630       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 2568      |
# |    time_elapsed     | 30        |
# |    total_timesteps  | 78649     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.027     |
# |    n_updates        | 7162      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 610       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 2492      |
# |    time_elapsed     | 32        |
# |    total_timesteps  | 80578     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.02      |
# |    n_updates        | 7644      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 606       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 2425      |
# |    time_elapsed     | 34        |
# |    total_timesteps  | 82801     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0273    |
# |    n_updates        | 8200      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 605       |
# |    ep_rew_mean      | -3.73e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 2339      |
# |    time_elapsed     | 36        |
# |    total_timesteps  | 85526     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0334    |
# |    n_updates        | 8881      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 594       |
# |    ep_rew_mean      | -3.74e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 2310      |
# |    time_elapsed     | 37        |
# |    total_timesteps  | 87041     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0339    |
# |    n_updates        | 9260      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 597       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 2275      |
# |    time_elapsed     | 39        |
# |    total_timesteps  | 89424     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0151    |
# |    n_updates        | 9855      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 605       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 2237      |
# |    time_elapsed     | 41        |
# |    total_timesteps  | 92275     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0291    |
# |    n_updates        | 10568     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 607       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 2211      |
# |    time_elapsed     | 42        |
# |    total_timesteps  | 94416     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.2      |
# |    n_updates        | 11103     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 605       |
# |    ep_rew_mean      | -3.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 2190      |
# |    time_elapsed     | 43        |
# |    total_timesteps  | 96281     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0138    |
# |    n_updates        | 11570     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 626       |
# |    ep_rew_mean      | -3.71e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 2147      |
# |    time_elapsed     | 46        |
# |    total_timesteps  | 100350    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.4      |
# |    n_updates        | 12587     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 633      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2122     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 102869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 13217    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 634       |
# |    ep_rew_mean      | -3.71e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 2096      |
# |    time_elapsed     | 50        |
# |    total_timesteps  | 105706    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0199    |
# |    n_updates        | 13926     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 641      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2070     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 109193   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.6     |
# |    n_updates        | 14798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 632      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2052     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 111940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 15484    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 612       |
# |    ep_rew_mean      | -3.69e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 2039      |
# |    time_elapsed     | 55        |
# |    total_timesteps  | 113987    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 78.1      |
# |    n_updates        | 15996     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 623      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2015     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 117557   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.6     |
# |    n_updates        | 16889    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 632       |
# |    ep_rew_mean      | -3.69e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 1994      |
# |    time_elapsed     | 60        |
# |    total_timesteps  | 121053    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0181    |
# |    n_updates        | 17763     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 661       |
# |    ep_rew_mean      | -3.69e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 1967      |
# |    time_elapsed     | 64        |
# |    total_timesteps  | 125968    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0146    |
# |    n_updates        | 18991     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 662      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1953     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 128652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 19662    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 662       |
# |    ep_rew_mean      | -3.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 1936      |
# |    time_elapsed     | 68        |
# |    total_timesteps  | 132163    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0243    |
# |    n_updates        | 20540     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 679      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1918     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 136779   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 21694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 685      |
# |    ep_rew_mean      | -3.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1910     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 138826   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 22206    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 707       |
# |    ep_rew_mean      | -3.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 212       |
# |    fps              | 1892      |
# |    time_elapsed     | 75        |
# |    total_timesteps  | 143304    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0255    |
# |    n_updates        | 23325     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 721       |
# |    ep_rew_mean      | -3.68e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 216       |
# |    fps              | 1879      |
# |    time_elapsed     | 77        |
# |    total_timesteps  | 146560    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0296    |
# |    n_updates        | 24139     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 735       |
# |    ep_rew_mean      | -3.67e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 1866      |
# |    time_elapsed     | 80        |
# |    total_timesteps  | 150421    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.5      |
# |    n_updates        | 25105     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 760       |
# |    ep_rew_mean      | -3.66e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 1853      |
# |    time_elapsed     | 83        |
# |    total_timesteps  | 154665    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0151    |
# |    n_updates        | 26166     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 786       |
# |    ep_rew_mean      | -3.66e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 1841      |
# |    time_elapsed     | 86        |
# |    total_timesteps  | 159132    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0196    |
# |    n_updates        | 27282     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 826       |
# |    ep_rew_mean      | -3.66e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 1823      |
# |    time_elapsed     | 90        |
# |    total_timesteps  | 165355    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0227    |
# |    n_updates        | 28838     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 846       |
# |    ep_rew_mean      | -3.56e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 1811      |
# |    time_elapsed     | 93        |
# |    total_timesteps  | 170090    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.6      |
# |    n_updates        | 30022     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 928       |
# |    ep_rew_mean      | -3.48e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 1790      |
# |    time_elapsed     | 100       |
# |    total_timesteps  | 179841    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0196    |
# |    n_updates        | 32460     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 979       |
# |    ep_rew_mean      | -3.49e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 1774      |
# |    time_elapsed     | 105       |
# |    total_timesteps  | 187310    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0169    |
# |    n_updates        | 34327     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.06e+03  |
# |    ep_rew_mean      | -3.28e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 1751      |
# |    time_elapsed     | 113       |
# |    total_timesteps  | 198054    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0245    |
# |    n_updates        | 37013     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.2e+03   |
# |    ep_rew_mean      | -3.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 1727      |
# |    time_elapsed     | 124       |
# |    total_timesteps  | 214517    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.4      |
# |    n_updates        | 41129     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.26e+03  |
# |    ep_rew_mean      | -3.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 1716      |
# |    time_elapsed     | 129       |
# |    total_timesteps  | 222190    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0194    |
# |    n_updates        | 43047     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.46e+03  |
# |    ep_rew_mean      | -2.96e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 1687      |
# |    time_elapsed     | 146       |
# |    total_timesteps  | 246780    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0413    |
# |    n_updates        | 49194     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | -2.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1675     |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 260573   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.4     |
# |    n_updates        | 52643    |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.79e+03  |
# |    ep_rew_mean      | -2.53e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 1655      |
# |    time_elapsed     | 171       |
# |    total_timesteps  | 284557    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0183    |
# |    n_updates        | 58639     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.05e+03  |
# |    ep_rew_mean      | -2.38e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 1638      |
# |    time_elapsed     | 192       |
# |    total_timesteps  | 314557    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0452    |
# |    n_updates        | 66139     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.24e+03  |
# |    ep_rew_mean      | -2.15e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 1626      |
# |    time_elapsed     | 206       |
# |    total_timesteps  | 335878    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 15.3      |
# |    n_updates        | 71469     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.45e+03  |
# |    ep_rew_mean      | -1.92e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 1614      |
# |    time_elapsed     | 222       |
# |    total_timesteps  | 359256    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.103     |
# |    n_updates        | 77313     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.66e+03  |
# |    ep_rew_mean      | -1.66e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 1600      |
# |    time_elapsed     | 239       |
# |    total_timesteps  | 383730    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0237    |
# |    n_updates        | 83432     |
# -----------------------------------

# %%
from stable_baselines3 import PPO # Importe o modelo do stable_baselines3

# Cria pasta de logs
log_dir_ppo = ".logs-pong/logs-ppo/"
os.makedirs(log_dir_ppo, exist_ok=True)

# Definindo o ambiente
env = gym.make(env_name)
env = Monitor(env, log_dir_ppo)

model = PPO("MlpPolicy", env, seed = 3, verbose = 1) # Defina o modelo
model.learn(total_timesteps = 400000) # Treine o modelo 400000
n_episodes = 50 # Defina o número de episódios 50

# Avaliando o agente e guardando o desempenho no dicionário
algorithms_dict = getValues(model, env, n_episodes, algorithms_dict)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 768      |
# |    ep_rew_mean     | -3.5e+03 |
# | time/              |          |
# |    fps             | 1943     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 733          |
# |    ep_rew_mean          | -3.6e+03     |
# | time/                   |              |
# |    fps                  | 1349         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033652538 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000259    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.16e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 6.49e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 756         |
# |    ep_rew_mean          | -3.69e+03   |
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009398676 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.8e+03     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 8.66e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 676         |
# |    ep_rew_mean          | -3.67e+03   |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009555986 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00429     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 8.68e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 719          |
# |    ep_rew_mean          | -3.62e+03    |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0027136174 |
# |    clip_fraction        | 0.00405      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.00775      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.44e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 1.2e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 730         |
# |    ep_rew_mean          | -3.59e+03   |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009780232 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 3.54e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | -3.56e+03   |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003542398 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0422      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.53e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 8.6e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 781         |
# |    ep_rew_mean          | -3.55e+03   |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006603432 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0426      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 3.28e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 783          |
# |    ep_rew_mean          | -3.61e+03    |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0030901222 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0414       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 8.53e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 809         |
# |    ep_rew_mean          | -3.6e+03    |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009434643 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0314      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 8.55e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 843          |
# |    ep_rew_mean          | -3.58e+03    |
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0012045589 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.0217       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 5.73e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 865         |
# |    ep_rew_mean          | -3.57e+03   |
# | time/                   |             |
# |    fps                  | 1162        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008705003 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.035       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.17e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 2.88e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 864         |
# |    ep_rew_mean          | -3.58e+03   |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014846299 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.0545      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.22e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 3.23e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 889          |
# |    ep_rew_mean          | -3.61e+03    |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 14           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0021750631 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.963       |
# |    explained_variance   | 0.0469       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 8.45e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 876          |
# |    ep_rew_mean          | -3.62e+03    |
# | time/                   |              |
# |    fps                  | 1158         |
# |    iterations           | 15           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0054101357 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 5.72e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 884          |
# |    ep_rew_mean          | -3.64e+03    |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0047609312 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.0394       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.07e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 5.94e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 888          |
# |    ep_rew_mean          | -3.63e+03    |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 17           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0009396728 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.0369       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 8.21e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 890          |
# |    ep_rew_mean          | -3.61e+03    |
# | time/                   |              |
# |    fps                  | 1153         |
# |    iterations           | 18           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0007972338 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.0423       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.97e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 5.9e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 876           |
# |    ep_rew_mean          | -3.6e+03      |
# | time/                   |               |
# |    fps                  | 1153          |
# |    iterations           | 19            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00027396952 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.804        |
# |    explained_variance   | 0.0478        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.06e+04      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00186      |
# |    value_loss           | 5.8e+04       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 882           |
# |    ep_rew_mean          | -3.6e+03      |
# | time/                   |               |
# |    fps                  | 1151          |
# |    iterations           | 20            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00029858222 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.796        |
# |    explained_variance   | 0.0588        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+05      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000869     |
# |    value_loss           | 8.34e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 894          |
# |    ep_rew_mean          | -3.56e+03    |
# | time/                   |              |
# |    fps                  | 1150         |
# |    iterations           | 21           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0007479923 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.796       |
# |    explained_variance   | 0.0723       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.85e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 3.1e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 894           |
# |    ep_rew_mean          | -3.57e+03     |
# | time/                   |               |
# |    fps                  | 1149          |
# |    iterations           | 22            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00030482936 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.816        |
# |    explained_variance   | 0.0622        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.42e+04      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 8.55e+04      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 882        |
# |    ep_rew_mean          | -3.58e+03  |
# | time/                   |            |
# |    fps                  | 1150       |
# |    iterations           | 23         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00209339 |
# |    clip_fraction        | 0.00366    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.824     |
# |    explained_variance   | 0.0919     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.13e+03   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00219   |
# |    value_loss           | 5.71e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | -3.56e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 24           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0035391063 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.0854       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 5.69e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 909          |
# |    ep_rew_mean          | -3.56e+03    |
# | time/                   |              |
# |    fps                  | 1154         |
# |    iterations           | 25           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0012650304 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.889       |
# |    explained_variance   | 0.0933       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.82e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 5.76e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | -3.56e+03    |
# | time/                   |              |
# |    fps                  | 1155         |
# |    iterations           | 26           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0052283257 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 0.0828       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 5.33e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | -3.57e+03    |
# | time/                   |              |
# |    fps                  | 1154         |
# |    iterations           | 27           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0028349825 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.31e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 2.99e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | -3.58e+03    |
# | time/                   |              |
# |    fps                  | 1154         |
# |    iterations           | 28           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0012868143 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.867       |
# |    explained_variance   | 0.0933       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 2.72e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 950          |
# |    ep_rew_mean          | -3.56e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 29           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0033721705 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.0913       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.4e+04      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 7.83e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | -3.57e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 30           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0018239254 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.33e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 2.98e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 957           |
# |    ep_rew_mean          | -3.57e+03     |
# | time/                   |               |
# |    fps                  | 1153          |
# |    iterations           | 31            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00030285172 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.871        |
# |    explained_variance   | 0.151         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.51e+03      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000781     |
# |    value_loss           | 2.98e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 963           |
# |    ep_rew_mean          | -3.57e+03     |
# | time/                   |               |
# |    fps                  | 1153          |
# |    iterations           | 32            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00032951345 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.872        |
# |    explained_variance   | 0.0911        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.48e+04      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000854     |
# |    value_loss           | 7.94e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 973           |
# |    ep_rew_mean          | -3.55e+03     |
# | time/                   |               |
# |    fps                  | 1152          |
# |    iterations           | 33            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00012964325 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.875        |
# |    explained_variance   | 0.0888        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.93e+03      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000993     |
# |    value_loss           | 5.49e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 967           |
# |    ep_rew_mean          | -3.55e+03     |
# | time/                   |               |
# |    fps                  | 1151          |
# |    iterations           | 34            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00045353032 |
# |    clip_fraction        | 0.00215       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.87         |
# |    explained_variance   | 0.139         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.64e+03      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.00209      |
# |    value_loss           | 2.95e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 967          |
# |    ep_rew_mean          | -3.55e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 35           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0043556667 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00646     |
# |    value_loss           | 5.15e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -3.55e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 36           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0010709253 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 3.31e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+03      |
# |    ep_rew_mean          | -3.55e+03     |
# | time/                   |               |
# |    fps                  | 1149          |
# |    iterations           | 37            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00021761359 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.92         |
# |    explained_variance   | 0.0924        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.51e+04      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 5.23e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -3.56e+03   |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 38          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002354694 |
# |    clip_fraction        | 0.00151     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.32e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 5.42e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -3.55e+03    |
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 39           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0008146043 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 5.38e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+03      |
# |    ep_rew_mean          | -3.52e+03     |
# | time/                   |               |
# |    fps                  | 1149          |
# |    iterations           | 40            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00016764097 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.959        |
# |    explained_variance   | 0.111         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.08e+03      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000651     |
# |    value_loss           | 5.29e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.01e+03      |
# |    ep_rew_mean          | -3.52e+03     |
# | time/                   |               |
# |    fps                  | 1150          |
# |    iterations           | 41            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00023615739 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.962        |
# |    explained_variance   | 0.119         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+04      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000856     |
# |    value_loss           | 5.46e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | -3.52e+03    |
# | time/                   |              |
# |    fps                  | 1151         |
# |    iterations           | 42           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0009954395 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 4.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+03     |
# |    ep_rew_mean          | -3.45e+03    |
# | time/                   |              |
# |    fps                  | 1152         |
# |    iterations           | 43           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0003908053 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 1e+04        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.04e+03      |
# |    ep_rew_mean          | -3.45e+03     |
# | time/                   |               |
# |    fps                  | 1153          |
# |    iterations           | 44            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 4.6047207e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.938        |
# |    explained_variance   | 0.134         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.35e+04      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000295     |
# |    value_loss           | 7.88e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+03     |
# |    ep_rew_mean          | -3.45e+03    |
# | time/                   |              |
# |    fps                  | 1154         |
# |    iterations           | 45           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0006328566 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.959       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.7e+03      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 2.9e+04      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.05e+03      |
# |    ep_rew_mean          | -3.44e+03     |
# | time/                   |               |
# |    fps                  | 1155          |
# |    iterations           | 46            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00032208386 |
# |    clip_fraction        | 0.00112       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.933        |
# |    explained_variance   | 0.148         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+03      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.00129      |
# |    value_loss           | 2.77e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+03     |
# |    ep_rew_mean          | -3.45e+03    |
# | time/                   |              |
# |    fps                  | 1156         |
# |    iterations           | 47           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0008887501 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.76e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 5.21e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.06e+03      |
# |    ep_rew_mean          | -3.44e+03     |
# | time/                   |               |
# |    fps                  | 1157          |
# |    iterations           | 48            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00045933737 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.934        |
# |    explained_variance   | 0.108         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.7e+04       |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 5.18e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | -3.44e+03    |
# | time/                   |              |
# |    fps                  | 1157         |
# |    iterations           | 49           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0004970017 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 3e+04        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.07e+03      |
# |    ep_rew_mean          | -3.37e+03     |
# | time/                   |               |
# |    fps                  | 1158          |
# |    iterations           | 50            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00069717644 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.924        |
# |    explained_variance   | 0.145         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+03      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.00164      |
# |    value_loss           | 2.36e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.07e+03      |
# |    ep_rew_mean          | -3.39e+03     |
# | time/                   |               |
# |    fps                  | 1159          |
# |    iterations           | 51            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00019749408 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.94         |
# |    explained_variance   | 0.143         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.08e+04      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000784     |
# |    value_loss           | 5.42e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -3.33e+03   |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 52          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.001039483 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.63e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 4.84e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | -3.32e+03    |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 53           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 9.088041e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+04     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000338    |
# |    value_loss           | 5.17e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.08e+03      |
# |    ep_rew_mean          | -3.32e+03     |
# | time/                   |               |
# |    fps                  | 1161          |
# |    iterations           | 54            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00014658607 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# ...
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 179         |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.005318134 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 200         |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00655    |
# |    value_loss           | 660         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.57e+03    |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 180         |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.002344267 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77e+03    |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00298    |
# |    value_loss           | 2.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.57e+03     |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 181          |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0010706801 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | 0.0705       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+03     |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 2.33e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.57e+03    |
# |    ep_rew_mean          | 15          |
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 182         |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.003792659 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.0661      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+03    |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.57e+03     |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 183          |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 0.0058693336 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.845       |
# |    explained_variance   | -0.0314      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00795     |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.62e+03    |
# |    ep_rew_mean          | 70          |
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 184         |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.008879349 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.0746      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 463         |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 964         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.64e+03     |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 185          |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 0.0011291375 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.0431       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.7e+03      |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000996    |
# |    value_loss           | 2.56e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.64e+03     |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 186          |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0005906282 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+04     |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 2.35e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.64e+03     |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 187          |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0050252425 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.871       |
# |    explained_variance   | 0.0261       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69e+03    |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 188         |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.008084096 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.00538     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 847         |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.69e+03      |
# |    ep_rew_mean          | 220           |
# | time/                   |               |
# |    fps                  | 1160          |
# |    iterations           | 189           |
# |    time_elapsed         | 333           |
# |    total_timesteps      | 387072        |
# | train/                  |               |
# |    approx_kl            | 0.00072348065 |
# |    clip_fraction        | 0.002         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.892        |
# |    explained_variance   | 0.048         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.45e+04      |
# |    n_updates            | 1880          |
# |    policy_gradient_loss | -0.00175      |
# |    value_loss           | 2.34e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69e+03    |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 190         |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.006171749 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -0.71       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.9        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 271         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.74e+03    |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 191         |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.012787731 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | -0.0283     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.4        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 990         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.76e+03     |
# |    ep_rew_mean          | 365          |
# | time/                   |              |
# |    fps                  | 1161         |
# |    iterations           | 192          |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0024595335 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.912       |
# |    explained_variance   | 0.0325       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84e+04     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.00348      |
# |    value_loss           | 2.19e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.76e+03     |
# |    ep_rew_mean          | 365          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 193          |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 395264       |
# | train/                  |              |
# |    approx_kl            | 0.0002974273 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.92        |
# |    explained_variance   | 0.0191       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.33e+03     |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 2.54e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.76e+03      |
# |    ep_rew_mean          | 365           |
# | time/                   |               |
# |    fps                  | 1160          |
# |    iterations           | 194           |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 397312        |
# | train/                  |               |
# |    approx_kl            | 0.00062674866 |
# |    clip_fraction        | 0.0019        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.914        |
# |    explained_variance   | 0.529         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.43e+03      |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | -0.00182      |
# |    value_loss           | 1.94e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.79e+03    |
# |    ep_rew_mean          | 435         |
# | time/                   |             |
# |    fps                  | 1160        |
# |    iterations           | 195         |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.005260952 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | -0.0422     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.4        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 228         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.79e+03     |
# |    ep_rew_mean          | 435          |
# | time/                   |              |
# |    fps                  | 1160         |
# |    iterations           | 196          |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0005267365 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.0655       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+03     |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 2.35e+04     |
# ------------------------------------------

# %% [markdown]
# A seguir, detalhe um pouco mais quais foram os algoritmos testados bem como a performance obtida por cada um.
#
# Este detalhamento pode ser feito por meio de um ou mais gráficos mostrando o desempenho dos modelos, ou simplesmente por texto.

# %%
### Espaço para o Piloto criar gráficos ou textos para mostrar os diferentes resultados entre modelos
algorithms_dict
# Out:
# {'A2C': {'mean_reward': 3850.0, 'std_reward': 593.7171043518958},
#  'DQN': {'mean_reward': 3320.0, 'std_reward': 1291.3558765886344},
#  'PPO': {'mean_reward': 3830.0, 'std_reward': 675.3517601961217}}

# %% [markdown]
# Observando puramente os resultados numéricos de cada modelo após os treinamentos, o destaque foi para o A2C (Advantage Actor Critic), que apresentou maior recompensa média e menor desvio padrão. O algoritmo PPO (Proximal Policy Optimization) obteve resultados muito próximos ao A2C, enquanto o DQN (Deep Q Learning) recebeu recompensas menores em médias e mais heterogêneas entre si.
#
# Vamos criar uma visualização gráfica para avaliar mais detalhadamente a performance de cada algoritmo.

# %%
from stable_baselines3.common import results_plotter
import matplotlib.pyplot as plt

def plot_results(log_folder, window=10, title="Curva de Aprendizado"):
    """
    Plota os resultados.

    :param log_folder: (str) diretório dos resultados a serem plotados
    :param window: (int) tamanho da janela da média móvel
    :param title: (str) título do plot
    """
    # Obtém os resultados
    results = results_plotter.load_results(log_folder)
    x, y = results_plotter.ts2xy(results, "timesteps")
    
    # Calcula a média móvel do retorno
    y_smoothed = results_plotter.rolling_window(y, window=window).mean(axis=1)
    
    # Plota os resultados
    fig = plt.figure(title, figsize=(10, 5))
    plt.scatter(x, y, s=2)
    plt.plot(x[window-1:], y_smoothed, color="darkblue", label="Média Móvel")
    plt.xlabel("Timesteps")
    plt.ylabel("Retorno Médio")
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_results(log_dir_a2c, title = "Curva de Aprendizado - A2C")

# %%
plot_results(log_dir_dqn, title = "Curva de Aprendizado - DQN")

# %%
plot_results(log_dir_ppo, title = "Curva de Aprendizado - PPO")

# %% [markdown]
# ### Escolha do Algoritmo
#
# Após testar e analisar diversos algoritmos diferentes, qual foi o escolhido?
#
# _Pergunta Extra:_ você usou algum critério para escolher quais algoritmos seriam testados?

# %%
### Qual foi o algoritmo escolhido?

# %% [markdown]
# ### Exercício 2 - Mudança de Hiperparâmetros
#
# No segundo exercício, você deve testar diferentes hiperparâmetros para seu modelo escolhido!
#
# Todos os modelos da Stable Baselines têm diversos parâmetros detalhados em sua documentação ([exemplo: PPO](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html#parameters)) que podem ser modificados para alterar o modelo.
#
# Para modificar os parâmetros de um algoritmo, tal como o ```PPO(...)```, basta especificá-los durante a construção do modelo, da seguinte forma:

# %%
model = PPO("MlpPolicy", env, seed=1, verbose=1,
           learning_rate=0.0007, gamma=0.9) # Especificando diferentes valores para a learning_rate e para o gamma

# %% [markdown]
# Se quiser, você também pode alterar a arquitetura das redes neurais do modelo, da seguinte forma:

# %%
import torch
import inspect

# Parâmetros das redes neurais
policy_kwargs = dict(activation_fn=torch.nn.ReLU,                # Troca a função de ativação para ReLU
                     net_arch=[dict(pi=[32, 32], vf=[32, 32])])  # Define a arquitetura das redes do Actor-Critic

# Cria o nosso modelo com os novos parâmetros
model = PPO("MlpPolicy", env, seed=1, verbose=1, 
            policy_kwargs=policy_kwargs) # Especificando outra arquitetura de rede

# %% [markdown]
# Caso queira ler um pouco mais sobre essas diferentes arquiteturas, recomendamos [a seguinte página da documentação da biblioteca.](https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html)
#
# A seguir, preparamos uma outra função útil para guardar os parâmetros testados:

# %%
def getValuesAndParams(model, env, n_episodes, info_dict):
    
    model_name = model.__class__.__name__
    env_name = env.unwrapped.__class__.__name__
    
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=n_episodes, deterministic=True)
    
    args = inspect.getfullargspec(model.__class__).args
    func_params_dict = {}
    for arg in args:
        p = model.__dict__.get(arg)
        if type(p) in [None, int, float, str, dict]:
            func_params_dict[arg] = p
    
    
    if model_name not in info_dict:
        info_dict[model_name] = {}
        
    if "env" not in info_dict[model_name]:
        info_dict[model_name]["env"] = []
        
    info_dict[model_name]["env"].append(env_name)
        
    if "mean_reward" not in info_dict[model_name]:
        info_dict[model_name]["mean_reward"] = []
        info_dict[model_name]["std_reward"] = []
        
    if "class_args" not in info_dict[model_name]:
        info_dict[model_name]["class_args"] = []
        
    info_dict[model_name]["mean_reward"].append(mean_reward)
    info_dict[model_name]["std_reward"].append(std_reward)
    info_dict[model_name]["class_args"].append(func_params_dict)
    
    params_dict = model.get_parameters()
    if "policy.optimizer" not in params_dict:
        if "actor.optimizer" not in info_dict[model_name]:
            info_dict[model_name]["actor.optimizer"] = []
            info_dict[model_name]["critic.optimizer"] = []

        info_dict[model_name]["actor.optimizer"] += params_dict["actor.optimizer"]["param_groups"]
        info_dict[model_name]["critic.optimizer"] += params_dict["critic.optimizer"]["param_groups"]
    
    else:
        if "policy.optimizer" not in info_dict[model_name]:
            info_dict[model_name]["policy.optimizer"] = []
    
        info_dict[model_name]["policy.optimizer"] += params_dict["policy.optimizer"]["param_groups"]
    
    return info_dict

parameters_dict = {}

# %% [markdown]
# A seguir, você está livre para testar diferentes hiperparâmetros para o algoritmo escolhido! Você deve testar valores diversos para pelo menos **dois** parâmetros. Se quiser algumas sugestões, recomendamos realizar testes no `gamma`, na `learning_rate` ou na arquitetura da rede neural do modelo.

# %%
from stable_baselines3 import ... # Importe o modelo do stable_baselines3

# Definindo o ambiente
env = ...

model = ... # Defina o modelo
model.learn(total_timesteps=...) # Treine o modelo
n_episodes = ... # Defina o número de episódios

# Avaliando o agente
parameters_dict = getValuesAndParams(model, env, n_episodes, parameters_dict)

# %%
### Espaço livre para a comparação dos hiperparâmetros
